# %%
def prefix_burst1(inputs,stack1,stack2,valid):
    '''put value in position of sp pointer next, 0 as null'''
    cnt = 0
    result_seq = []
    value = 1
    operator = 0
    """Read value into stack1"""
    while valid:
        stack1.append(inputs)
    
    """Reverse the prefix sequence put it into another stack and do operation
    at the same time"""
    while stack1 != 0:
        stack_top = stack1.first()
        if stack_top == value:
            stack2.append(stack1.pop()) 
        elif stack_top == operator:
            value1 = stack2.pop()
            value2 = stack2.pop()
            
            if unsigned_value == 0:
                result = value1 + value2
            if unsigned_value == 1:
                result = value1 - value2
            if unsigned_value == 2:
                result = value1 * value2
            if unsigned_value == 3:
                result = value1 + value2
            stack2.push(result)
        
        if cnt == 2:
            result_seq.append(stack2.pop()) 
            cnt =0
        else:
            cnt += 1

    sorted_descend = result_seq.sort()
    return sorted_descend


def prefix1(inputs,stack1,stack2,valid):
    result = 0
    value = 1
    operator = 0
    """Read value into stack1"""
    while valid:
        stack1.append(inputs)
    while stack1 != 0:
        stack_top = stack1.first()
        if stack_top == value:
            stack2.append(stack1.pop()) 
        else:
            value1 = stack2.pop()
            value2 = stack2.pop()
            if unsigned_value == 0:
                result = value1 + value2
            if unsigned_value == 1:
                result = value1 - value2
            if unsigned_value == 2:
                result = value1 * value2
            if unsigned_value == 3:
                result = value1 + value2
            stack2.push(result)
        
    
    result = stack2.pop()
    
    return result

def postfix_burst(inputs,stack1,valid):
    '''put value in position of sp pointer next, 0 as null'''
    value = 1
    operator = 0
    cnt = 0
    result_seq = []
    """Read value into stack1"""
    while valid:
        if inputs == value:
            stack1.push(inputs)
        elif inputs == operator:
            "Note the operation of value is reversed here"
            value2 = stack1.pop() 
            value1 = stack1.pop()
            
            if unsigned_value == 0:
                result = value1 + value2
            if unsigned_value == 1:
                result = value1 - value2
            if unsigned_value == 2:
                result = value1 * value2
            if unsigned_value == 3:
                result = value1 + value2
            stack1.push(result)
        
        if cnt == 2:
            result_seq.append(stack1.pop()) 
            cnt =0
        else:
            cnt += 1
            
    sorted_ascend = result_seq.sort()
    
    return sorted_ascend

def postfix():
    '''put value in position of sp pointer next, 0 as null'''
    value = 1
    operator = 0
    """Read value into stack1"""
    while valid:
        if inputs == value:
            stack1.push(inputs)
        elif inputs == operator:
            "Note the operation of value is reversed here"
            value2 = stack1.pop() 
            value1 = stack1.pop()
            
            if unsigned_value == 0:
                result = value1 + value2
            if unsigned_value == 1:
                result = value1 - value2
            if unsigned_value == 2:
                result = value1 * value2
            if unsigned_value == 3:
                result = value1 + value2
            stack1.push(result)
    
    result = stack1.pop()
    
    return result




stack1 = []
stack2 = []
unsigned_value = 0
type_signal = 0
mode = 0
valid = 1
inputs = (unsigned_value, type_signal)

if type_signal == 1:
    operator = (unsigned_value,type_signal)
elif type_signal == 0:
    operand  = (unsigned_value,type_signal) 
    
match mode:
    case 0:
        prefix_burst(inputs,stack1,stack2,valid)
    case 1:
        postfix_burst()
    case 2:
        prefix()
    case 3:
        postfix()
    case _:
        print("ERROR")
